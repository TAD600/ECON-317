# %% [markdown]
# # Problem 1
#
# The first paragraph of the book "Poor Economics" by Banerjee and Duflo,

# %%
text = '''every year, 9million children die before their fifth
birthday.   A woman in sub-Saharan Africa has a
one-in-thirty chance of dying while giving birth—in
the developed world, the chance is one in 5,600.
There are at least twenty-five countries, most of
them in sub-Saharan Africa, where the average person
is expected to live no more than fifty-five years.
In india alone, more than 50 million school-going
Children cannot read a very simple text.  
This is the kind of paragraph that might make you
want to shut this book and, ideally  , forget about this
whole business of world poverty: The problem
seems too big, too intractable. Our goal with this
book is to persuade you not to'''

# %% [markdown]
# 1. Format the text using built in functions so that the text is grammatically correct.
# 2. How many words are there in this paragraph?
#    Hint: Don't count the punctuations as words.
# 3. How many unique word are there in this text?
#    Hint: Don't count the punctuations as words.
# 4. How common are certain words - 'is', 'the', 'a', 'year'.
#    Hint: Create a dictionary with the with the above words as keys and the count of those words as lists and print the answer as,
#    is appears W times.
#    the appears X times.
#    a appears Y times.
#    year appears Z times.
# 5. Sort the words alphabetically and print the first 20 unique words.

# %%
# Answer of Problem 1
text = text.replace('  ',' ').replace(':','.').replace('\n', ' ').replace(' ,', ',').replace('the problem', 'The problem').replace('9million', '9 million').replace('schoolgoing', 'school going').replace('cannot', 'can not')

# %%
text = text.replace('every year', 'Every year').replace('birth—in', 'birth. In').replace('  ', ' ').replace('india', 'India')

# %%
text = text.replace(' our', ' Our').replace('sub', 'Sub').replace('  a woman', ' A woman').replace('africa', 'Africa').replace(' in India', ' In India') + '.'

# %%
text
# Out:
# 'Every year, 9 million children die before their fifth birthday. A woman in Sub-Saharan Africa has a one-in-thirty chance of dying while giving birth. In the developed world, the chance is one in 5,600. There are at least twenty-five countries, most of them in Sub-Saharan Africa, where the average person is expected to live no more than fifty-five years. In India alone, more than 50 million school-going Children can not read a very simple text. This is the kind of paragraph that might make you want to shut this book and, ideally, forget about this whole business of world poverty. The problem seems too big, too intractable. Our goal with this book is to persuade you not to.'

# %%
# Answer of Problem 2

# %%
text = text.replace('.', '').replace(',', '').replace('"', '').replace('-', '')
text = text.replace(':', '')

# %%
words= text.lower().split()

# %%
len(words)
# Out:
# 118

# %%
len(words)
# Out:
# 118

# %%
# Answer of Problem 3

# %%
unique_words = set(words)

# %%
len(unique_words)
# Out:
# 84

# %%
# Answer of Problem 4
word_dic = {'is': words.count('is'), 'the': words.count('the'), 'a': words.count('a'),
           'year': words.count('year')}
print(word_dic)
# Out:
# {'is': 4, 'the': 5, 'a': 3, 'year': 1}

# %%
print('is:', word_dic['is'])   
print('the:', word_dic['the'])   
print('a:', word_dic['a'])   
print('year:', word_dic['year'])
# Out:
# is: 4
# the: 5
# a: 3
# year: 1

# %%
# Answer of Problem 5

# %%
sorted_list = sorted(unique_words)

# %%
sorted_list
# Out:
# ['50',
#  '5600',
#  '9',
#  'a',
#  'about',
#  'africa',
#  'alone',
#  'and',
#  'are',
#  'at',
#  'average',
#  'before',
#  'big',
#  'birth',
#  'birthday',
#  'book',
#  'business',
#  'can',
#  'chance',
#  'children',
#  'countries',
#  'developed',
#  'die',
#  'dying',
#  'every',
#  'expected',
#  'fifth',
#  'fiftyfive',
#  'forget',
#  'giving',
#  'goal',
#  'has',
#  'ideally',
#  'in',
#  'india',
#  'intractable',
#  'is',
#  'kind',
#  'least',
#  'live',
#  'make',
#  'might',
#  'million',
#  'more',
#  'most',
#  'no',
#  'not',
#  'of',
#  'one',
#  'oneinthirty',
#  'our',
#  'paragraph',
#  'person',
#  'persuade',
#  'poverty',
#  'problem',
#  'read',
#  'schoolgoing',
#  'seems',
#  'shut',
#  'simple',
#  'subsaharan',
#  'text',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'there',
#  'this',
#  'to',
#  'too',
#  'twentyfive',
#  'very',
#  'want',
#  'where',
#  'while',
#  'whole',
#  'with',
#  'woman',
#  'world',
#  'year',
#  'years',
#  'you']

# %%
print('First ten words in alphabetical order:', sorted_list[3:23])
# Out:
# First ten words in alphabetical order: ['a', 'about', 'africa', 'alone', 'and', 'are', 'at', 'average', 'before', 'big', 'birth', 'birthday', 'book', 'business', 'can', 'chance', 'children', 'countries', 'developed', 'die']

# %% [markdown]
# ### Marks Distribution
#
# | Problem | Mark     | Comment
# |:-------:|:--------:|:----------------------
# | 1       |   /2    |
# | 2       |   /2    |
# | 3       |   /2    |
# | 4       |   /3    |
# | 5       |   /1    |
#
# |**Total**|**/10**  |
